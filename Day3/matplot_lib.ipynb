# %%
import matplotlib.pyplot as plt
import numpy

x = numpy.arange(0, numpy.pi * 4, 0.1)
y1 = numpy.sin(x)
y2 = numpy.cos(x)

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Biểu đồ đường sin & cos")
# Out:
# Text(0.5, 1.0, 'Biểu đồ đường sin & cos')
