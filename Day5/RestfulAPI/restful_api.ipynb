# %% [markdown]
# # JSON IN PYTHON

# %%
import json

python_language = {
    "language": "Python",
    "author": "Rossum"
}

json_string = json.dumps(python_language)
json_string
# Out:
# '{"language": "Python", "author": "Rossum"}'
